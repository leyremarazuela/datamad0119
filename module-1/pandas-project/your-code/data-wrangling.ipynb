# %% [markdown]
# ## Pandas Project

# %% [markdown]
# # Step 0 : Importing libraries and dataset

# %%
# Import 2 libraries
import pandas as pd 
import numpy as np

# %%
# Import our dataset
data = pd.read_csv('./heart.csv')

# %% [markdown]
# # Step 1 : Understand Info contained in Data & Examinine Data for Potential Issues

# %%
display(data.head())
# Out:
#   chest pain type (4 values)  age in years  sex (1 = male; 0 = female)  \
# 0                  Very High            63                           1
# 1                       High            37                           1
# 2                   Moderate            41                           0
# 3                   Moderate            56                           1
# 4                        Low            57                           0
#
#   resting blood pressure   number of major vessels  exercise induced angina  \
# 0                Moderate                        0                        0
# 1                     Low                        0                        0
# 2                     Low                        0                        0
# 3                     Low                        0                        0
# 4                     Low                        0                        1
#
#     oldpeak  slope of the peak  thal  target
# 0       Low                  0     1       1
# 1  Moderate                  0     2       1
# 2       Low                  2     2       1
# 3  Very Low                  2     2       1
# 4  Very Low                  2     2       1

# %%
data.describe()
# Out:
#        age in years  sex (1 = male; 0 = female)  number of major vessels  \
# count    301.000000                  301.000000               301.000000
# mean      54.378738                    0.684385                 0.720930
# std        9.033793                    0.465534                 1.007568
# min       29.000000                    0.000000                 0.000000
# 25%       48.000000                    0.000000                 0.000000
# 50%       55.000000                    1.000000                 0.000000
# 75%       61.000000                    1.000000                 1.000000
# max       77.000000                    1.000000                 4.000000
#
#        exercise induced angina  slope of the peak        thal      target
# count               301.000000         301.000000  301.000000  301.000000
# mean                  0.328904           1.398671    2.312292    0.541528
# std                   0.470597           0.616872    0.612766    0.499102
# min                   0.000000           0.000000    0.000000    0.000000
# 25%                   0.000000           1.000000    2.000000    0.000000
# 50%                   0.000000           1.000000    2.000000    1.000000
# 75%                   1.000000           2.000000    3.000000    1.000000
# max                   1.000000           2.000000    3.000000    1.000000

# %%
data.shape
# Out:
# (301, 10)

# %%
data.dtypes
# Out:
# chest pain type (4 values)    object
# age in years                   int64
# sex (1 = male; 0 = female)     int64
# resting blood pressure        object
# number of major vessels        int64
# exercise induced angina        int64
# oldpeak                       object
# slope of the peak              int64
# thal                           int64
# target                         int64
# dtype: object

# %% [markdown]
# # Step 2 : Cleaning Data

# %% [markdown]
# ### Missing Values

# %%
# Find how prevalent missing values are in our data 
null_cols = data.isnull().sum()
null_cols[null_cols > 0]
null_cols
# Out:
# chest pain type (4 values)    0
# age in years                  0
# sex (1 = male; 0 = female)    0
# resting blood pressure        0
# number of major vessels       0
# exercise induced angina       0
# oldpeak                       0
# slope of the peak             0
# thal                          0
# target                        0
# dtype: int64

# %% [markdown]
# ### Incorrect Values

# %%
# Find any incorrect data-type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
# chest pain type (4 values)    301 non-null object
# age in years                  301 non-null int64
# sex (1 = male; 0 = female)    301 non-null int64
# resting blood pressure        301 non-null object
# number of major vessels       301 non-null int64
# exercise induced angina       301 non-null int64
# oldpeak                       301 non-null object
# slope of the peak             301 non-null int64
# thal                          301 non-null int64
# target                        301 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 23.6+ KB

# %%
# All values seem correct
# Investigate why oldpeak is float64
print(data["oldpeak"])
# Out:
# 0           Low
# 1      Moderate
# 2           Low
# 3      Very Low
# 4      Very Low
# 5      Very Low
# 6           Low
# 7      Very Low
# 8      Very Low
# 9           Low
# 10     Very Low
# 11     Very Low
# 12     Very Low
# 13          Low
# 14     Very Low
# 15          Low
# 16     Very Low
# 17     Moderate
# 18          Low
# 19          Low
# 20     Very Low
# 21     Very Low
# 22     Very Low
# 23     Very Low
# 24          Low
# 25     Very Low
# 26          Low
# 27     Very Low
# 28     Very Low
# 29     Very Low
#          ...
# 271    Very Low
# 272    Very Low
# 273    Very Low
# 274         Low
# 275    Very Low
# 276    Very Low
# 277    Moderate
# 278         Low
# 279    Very Low
# 280         Low
# 281    Very Low
# 282         Low
# 283         Low
# 284    Very Low
# 285    Very Low
# 286    Moderate
# 287         Low
# 288    Very Low
# 289        High
# 290    Moderate
# 291    Very Low
# 292    Moderate
# 293        High
# 294    Very Low
# 295    Very Low
# 296    Very Low
# 297    Very Low
# 298    Moderate
# 299    Very Low
# 300    Very Low
# Name: oldpeak, Length: 301, dtype: object

# %%
# Makes sense after seing printed output since heart rate is very sensitive and even decimal places matters. This ST depression induced by exercise relative to rest.

# %% [markdown]
# ### Low Variance Columns

# %%
low_variance = []

for col in data._get_numeric_data():
    minimum = min(data[col])
    ninety_perc = np.percentile(data[col], 90)
    if ninety_perc == minimum:
        low_variance.append(col)

print(low_variance)
# Out:
# []

# %% [markdown]
# ### Outliers -> Percentiles

# %%
#Find what cols still have low variance (though not as low as before)

low_variance2 = []

for col in data._get_numeric_data():
    minimum = min(data[col])
    ninety_perc = np.percentile(data[col], 85)
    if ninety_perc == minimum:
        low_variance2.append(col)

print(low_variance2)
# Out:
# []

# %%
# Do research understand if "fbs" is outlier or not
# 1) What is Fbs?  A test to determine how much glucose (sugar) is in a blood sample after an overnight fast. The fasting blood glucose test is commonly used to detect diabetes mellitus. A blood sample is taken in a lab, physician's office, or hospital. The test is done in the morning, before the person has eaten. 
# 2) What is a normal Fbs? The US Federal Drug Administration allows home glucose monitors to have a variance of 15% in results. That means a reading of 100 mg/dl might actually be as low as 85 mg/dl or as high as 115, a huge variation
# Conc) Maintain column since variance is accepted in general health guidelines.

# %% [markdown]
# ### Extreme Values -> IQR

# %%
stats = data.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                             count       mean       std   min   25%   50%  \
# age in years                301.0  54.378738  9.033793  29.0  48.0  55.0
# sex (1 = male; 0 = female)  301.0   0.684385  0.465534   0.0   0.0   1.0
# number of major vessels     301.0   0.720930  1.007568   0.0   0.0   0.0
# exercise induced angina     301.0   0.328904  0.470597   0.0   0.0   0.0
# slope of the peak           301.0   1.398671  0.616872   0.0   1.0   1.0
# thal                        301.0   2.312292  0.612766   0.0   2.0   2.0
# target                      301.0   0.541528  0.499102   0.0   0.0   1.0
#
#                              75%   max   IQR
# age in years                61.0  77.0  13.0
# sex (1 = male; 0 = female)   1.0   1.0   1.0
# number of major vessels      1.0   4.0   1.0
# exercise induced angina      1.0   1.0   1.0
# slope of the peak            2.0   2.0   1.0
# thal                         3.0   3.0   1.0
# target                       1.0   1.0   1.0

# %%
outliers = pd.DataFrame(columns=data.columns)

for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 3
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = data[(data[col] < lower) | 
                   (data[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
    
outliers
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Empty DataFrame
# Columns: [Outlier, age in years, chest pain type (4 values), exercise induced angina, number of major vessels, oldpeak, resting blood pressure , sex (1 = male; 0 = female), slope of the peak, target, thal]
# Index: []

# %%
#all but one value in outliers is fbs. Fbs stands for fasting blood sugar and data being very dispersed is normal, so we will only focus on understanding the other outlier.

# %%
#outlier with value col has maximum level of serum cholestoral in mg/dl in the whole dataset. It exceeds the mean (246) and distorts the data.

# %%
data = data.drop(index = 85)
data
# Out:
#     chest pain type (4 values)  age in years  sex (1 = male; 0 = female)  \
# 0                    Very High            63                           1
# 1                         High            37                           1
# 2                     Moderate            41                           0
# 3                     Moderate            56                           1
# 4                          Low            57                           0
# 5                          Low            57                           1
# 6                     Moderate            56                           0
# 7                     Moderate            44                           1
# 8                         High            52                           1
# 9                         High            57                           1
# 10                         Low            54                           1
# 11                        High            48                           0
# 12                    Moderate            49                           1
# 13                   Very High            64                           1
# 14                   Very High            58                           0
# 15                        High            50                           0
# 16                        High            58                           0
# 17                   Very High            66                           0
# 18                         Low            43                           1
# 19                   Very High            69                           0
# 20                         Low            59                           1
# 21                        High            44                           1
# 22                         Low            42                           1
# 23                        High            61                           1
# 24                   Very High            40                           1
# 25                    Moderate            71                           0
# 26                        High            59                           1
# 27                        High            51                           1
# 28                        High            65                           0
# 29                        High            53                           1
# ..                         ...           ...                         ...
# 271                        Low            58                           1
# 272                        Low            47                           1
# 273                        Low            52                           1
# 274                        Low            58                           1
# 275                   Moderate            57                           1
# 276                   Moderate            58                           0
# 277                        Low            61                           1
# 278                        Low            42                           1
# 279                        Low            52                           1
# 280                       High            59                           1
# 281                        Low            40                           1
# 282                        Low            61                           1
# 283                        Low            46                           1
# 284                  Very High            59                           1
# 285                   Moderate            57                           1
# 286                        Low            57                           1
# 287                        Low            55                           0
# 288                        Low            61                           1
# 289                        Low            58                           1
# 290                        Low            58                           0
# 291                       High            67                           1
# 292                        Low            44                           1
# 293                        Low            63                           1
# 294                        Low            63                           0
# 295                        Low            59                           1
# 296                        Low            57                           0
# 297                  Very High            45                           1
# 298                        Low            68                           1
# 299                        Low            57                           1
# 300                   Moderate            57                           0
#
#     resting blood pressure   number of major vessels  exercise induced angina  \
# 0                  Moderate                        0                        0
# 1                       Low                        0                        0
# 2                       Low                        0                        0
# 3                       Low                        0                        0
# 4                       Low                        0                        1
# 5                  Moderate                        0                        0
# 6                  Moderate                        0                        0
# 7                       Low                        0                        0
# 8                      High                        0                        0
# 9                  Moderate                        0                        0
# 10                 Moderate                        0                        0
# 11                      Low                        0                        0
# 12                      Low                        0                        0
# 13                 Very Low                        0                        1
# 14                 Moderate                        0                        0
# 15                      Low                        0                        0
# 16                      Low                        0                        0
# 17                 Moderate                        0                        0
# 18                 Moderate                        0                        0
# 19                 Moderate                        2                        0
# 20                      Low                        0                        0
# 21                      Low                        0                        1
# 22                 Moderate                        0                        0
# 23                 Moderate                        0                        1
# 24                 Moderate                        0                        1
# 25                     High                        2                        0
# 26                 Moderate                        0                        0
# 27                 Very Low                        0                        0
# 28                 Moderate                        1                        0
# 29                      Low                        0                        0
# ..                      ...                      ...                      ...
# 271                Very Low                        1                        0
# 272                Very Low                        1                        1
# 273                     Low                        2                        0
# 274                Moderate                        1                        0
# 275                     Low                        0                        0
# 276                     Low                        2                        0
# 277                Moderate                        1                        1
# 278                     Low                        0                        1
# 279                     Low                        0                        1
# 280                     Low                        1                        0
# 281                Moderate                        0                        0
# 282                Moderate                        1                        1
# 283                Moderate                        2                        1
# 284                     Low                        2                        0
# 285                Moderate                        1                        0
# 286                Very Low                        1                        1
# 287                     Low                        1                        1
# 288                Moderate                        1                        0
# 289                Very Low                        3                        0
# 290                    High                        2                        1
# 291                Moderate                        0                        0
# 292                     Low                        0                        1
# 293                Moderate                        2                        1
# 294                     Low                        0                        1
# 295                    High                        2                        0
# 296                Moderate                        0                        1
# 297                Very Low                        0                        0
# 298                Moderate                        2                        0
# 299                     Low                        1                        1
# 300                     Low                        1                        0
#
#       oldpeak  slope of the peak  thal  target
# 0         Low                  0     1       1
# 1    Moderate                  0     2       1
# 2         Low                  2     2       1
# 3    Very Low                  2     2       1
# 4    Very Low                  2     2       1
# 5    Very Low                  1     1       1
# 6         Low                  1     2       1
# 7    Very Low                  2     3       1
# 8    Very Low                  2     3       1
# 9         Low                  2     2       1
# 10   Very Low                  2     2       1
# 11   Very Low                  2     2       1
# 12   Very Low                  2     2       1
# 13        Low                  1     2       1
# 14   Very Low                  2     2       1
# 15        Low                  1     2       1
# 16   Very Low                  2     2       1
# 17   Moderate                  0     2       1
# 18        Low                  2     2       1
# 19        Low                  2     2       1
# 20   Very Low                  1     3       1
# 21   Very Low                  2     2       1
# 22   Very Low                  2     2       1
# 23   Very Low                  1     2       1
# 24        Low                  2     3       1
# 25   Very Low                  2     2       1
# 26        Low                  2     2       1
# 27   Very Low                  2     2       1
# 28   Very Low                  2     2       1
# 29   Very Low                  0     2       1
# ..        ...                ...   ...     ...
# 271  Very Low                  2     3       0
# 272  Very Low                  1     2       0
# 273  Very Low                  2     3       0
# 274       Low                  1     3       0
# 275  Very Low                  2     3       0
# 276  Very Low                  2     2       0
# 277  Moderate                  1     2       0
# 278       Low                  1     1       0
# 279  Very Low                  1     0       0
# 280       Low                  1     1       0
# 281  Very Low                  2     3       0
# 282       Low                  2     3       0
# 283       Low                  1     3       0
# 284  Very Low                  2     2       0
# 285  Very Low                  2     2       0
# 286  Moderate                  1     3       0
# 287       Low                  1     3       0
# 288  Very Low                  2     3       0
# 289      High                  0     1       0
# 290  Moderate                  1     1       0
# 291  Very Low                  1     3       0
# 292  Moderate                  0     1       0
# 293      High                  2     3       0
# 294  Very Low                  1     2       0
# 295  Very Low                  1     1       0
# 296  Very Low                  1     3       0
# 297  Very Low                  1     3       0
# 298  Moderate                  1     3       0
# 299  Very Low                  1     3       0
# 300  Very Low                  1     2       0
#
# [300 rows x 10 columns]

# %% [markdown]
# ### Finding and Removing Duplicates

# %%
before = len(data)
data = data.drop_duplicates()
after = len(data)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  4

# %% [markdown]
# # Step 3 : Manipulating Data

# %% [markdown]
# ### Renaming Columns

# %%
data.columns
# Out:
# Index(['chest pain type (4 values)', 'age in years',
#        'sex (1 = male; 0 = female)', 'resting blood pressure ',
#        'number of major vessels', 'exercise induced angina', 'oldpeak',
#        'slope of the peak', 'thal', 'target'],
#       dtype='object')

# %%
data.columns = ['age in years', 'sex (1 = male; 0 = female)', 'chest pain type (4 values)', 'resting blood pressure ', 'chol', 'fasting blood sugar', 'restecg', 'maximum heart rate achieved','exercise induced angina', 'oldpeak', 'slope of the peak', 'number of major vessels', 'thal', 'target']

data.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-dba961f28f39> in <module>
# ----> 1 data.columns = ['age in years', 'sex (1 = male; 0 = female)', 'chest pain type (4 values)', 'resting blood pressure ', 'chol', 'fasting blood sugar', 'restecg', 'maximum heart rate achieved','exercise induced angina', 'oldpeak', 'slope of the peak', 'number of major vessels', 'thal', 'target']
#       2
#       3 data.columns
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    3321             raise ValueError(
#    3322                 'Length mismatch: Expected axis has {old} elements, new '
# -> 3323                 'values have {new} elements'.format(old=old_len, new=new_len))
#    3324
#    3325         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 10 elements, new values have 14 elements

# %% [markdown]
# ### Changing Column Order

# %%
#The "goal" field refers to the presence of heart disease in the patient. It is integer valued from 0 (no presence) to 4. The rest in logical order preferred.

column_order = ['chest pain type (4 values)','age in years', 'sex (1 = male; 0 = female)', 'resting blood pressure ','number of major vessels','exercise induced angina', 'oldpeak', 'slope of the peak','thal', 'target'] 
                

data = data[column_order]
data.head()

# %% [markdown]
# ### Binning Numeric Variables

# %%
mpg_labels = ['Low', 'Moderate', 'High', 'Very High']
bins = pd.cut(data['chest pain type (4 values)'],4, labels=mpg_labels)
bins.head(10)

# %%
mpg_labels2 = ['Very Low', 'Low', 'Moderate', 'High', 'Very High']
bins2 = pd.cut(data['oldpeak'],5, labels=mpg_labels2)
bins2.head(10)

# %%
mpg_labels3 = ['Very Low', 'Low', 'Moderate', 'High', 'Very High']
bins3 = pd.cut(data['resting blood pressure '],5, labels=mpg_labels3)
bins3.head(10)

# %% [markdown]
# ### Substituting Binned Variables

# %%
data['chest pain type (4 values)'] = bins
data['oldpeak'] = bins2
data['resting blood pressure '] = bins3

data.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c419478127c0> in <module>
# ----> 1 data['chest pain type (4 values)'] = bins
#       2 data['oldpeak'] = bins2
#       3 data['resting blood pressure '] = bins3
#       4
#       5 data.head(20)
#
# NameError: name 'bins' is not defined

# %% [markdown]
# # Step 4 : Export clean CSV version of data

# %%
data.to_csv('./heart.csv', index=False)
